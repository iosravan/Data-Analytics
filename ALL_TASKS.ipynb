# %%
import pandas as pd
import numpy as np
import os, collections, csv
import cProfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#df1 = pd.read_excel('/content/drive/My Drive/data.xlsx')
#df2 = pd.read_excel('/content/drive/My Drive/data_1.xlsx')

# %% [markdown]
# # 1

# %%
df1 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1')
df2 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_1')
df3 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_2')
df4 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_3')
df5 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_4')
df6 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_5')
df7 = pd.read_excel('/content/drive/My Drive/data.xlsx', sheet_name ='Detail_67_1_1_6')

# %%
frames1 = [df1, df2, df3, df4, df5, df6, df7]
final_df = pd.concat(frames1)
final_df.to_csv('detailZ.csv')
print("CSV file :'detail.csv' created")
# Out:
# CSV file :'detail.csv' created

# %%
frames2 = [df1, df2, df3, df4, df5, df6, df7]
final_df = pd.concat(frames2)
final_df.to_csv('detailvol1.csv')
print("CSV file :'detailvol.csv' created")
# Out:
# CSV file :'detailvol.csv' created

# %%
frames3 = [df1, df2, df3, df4, df5, df6, df7]
final_df = pd.concat(frames3)
final_df.to_csv('detailtemp.csv')
print("CSV file :'detailtemp.csv' created")
# Out:
# CSV file :'detailtemp.csv' created

# %% [markdown]
# # 2

# %%
#DetailDownsampled
df = pd.read_csv('/content/detailZ.csv', parse_dates = ["Absolute Time"], index_col = "Absolute Time")
df = df.resample('T').mean()
df.to_csv('detailDownsampled.csv')

# %%
#detailVolDownsampled
df = pd.read_csv('/content/detailvol1.csv', parse_dates = ["Relative Time(h:min:s.ms)"], index_col = "Relative Time(h:min:s.ms)")
df = df.resample('T').mean()
df.to_csv('detailVolDownsampled.csv')

# %%
# detailTempDownsampled
df = pd.read_csv('/content/detailtemp.csv', parse_dates = ["Relative Time(h:min:s.ms)"], index_col = "Relative Time(h:min:s.ms)")
df = df.resample('T').mean()
df.to_csv('detailTempDownsampled.csv')

# %% [markdown]
# # 3

# %%
SET=pd.read_csv(r'/content/detailVolDownsampled.csv')
SET.plot()

# %% [markdown]
# # 4

# %%
def ds():
    df = pd.read_csv('/content/detailZ.csv', parse_dates = ["Relative Time(h:min:s.ms)"], index_col = "Relative Time(h:min:s.ms)")
    df = df.resample('T').mean()

# %%
def dsv():
    df = pd.read_csv('/content/detailvol.csv', parse_dates = ["Relative Time(h:min:s.ms)"], index_col = "Relative Time(h:min:s.ms)")
    df = df.resample('T').mean()

# %%
def dst():
    df = pd.read_csv('/content/detailtemp.csv', parse_dates = ["Relative Time(h:min:s.ms)"], index_col = "Relative Time(h:min:s.ms)")
    df = df.resample('T').mean()

# %%
cProfile.run('ds()')
# Out:
#          67100310 function calls (67100194 primitive calls) in 39.948 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#        15    0.000    0.000    0.018    0.001 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
# ...

# %%
cProfile.run('dsv()')
# Out:
#          67100310 function calls (67100194 primitive calls) in 39.969 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#        15    0.000    0.000    0.016    0.001 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
# ...

# %%
cProfile.run('dst()')
# Out:
#          67100310 function calls (67100194 primitive calls) in 39.776 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#        15    0.000    0.000    0.016    0.001 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
# ...

# %% [markdown]
# # 5

# %%
import unittest

class TestStringMethods(unittest.TestCase):

    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')

    def test_isupper(self):
        self.assertTrue('FOO'.isupper())
        self.assertFalse('Foo'.isupper())

    def test_split(self):
        s = 'Nunam Tech'
        self.assertEqual(s.split(), ['Nunam', 'Tech'])
        with self.assertRaises(TypeError):
            s.split(2)

if __name__ == '__main__':
    unittest.main()
# Out:
# E
# ...
# ERROR: /root/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
